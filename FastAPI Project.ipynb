# %%
import sys
# !{sys.executable} -m pip freeze > requirements.txt

# %%
import os
print(os.getcwd())
# Out:
# C:\Jupyter Notebook

# %%
pip install fastapi uvicorn
# Out:
# Requirement already satisfied: fastapi in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.141.1)
# Requirement already satisfied: uvicorn in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.52.4)
# Requirement already satisfied: starlette>=0.46.0 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastapi) (1.6.0)
# Requirement already satisfied: pydantic>=2.9.0 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastapi) (2.13.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastapi) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastapi) (0.4.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastapi) (0.0.5)
# Requirement already satisfied: click>=7.0 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from uvicorn) (8.5.0)
# Requirement already satisfied: h11>=0.8 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic>=2.9.0->fastapi) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic>=2.9.0->fastapi) (2.46.5)
# Requirement already satisfied: anyio<5,>=3.6.2 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from starlette>=0.46.0->fastapi) (4.15.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (3.19)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages (26.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile FastApi.py
from fastapi import FastAPI
app=FastAPI()

@app.get("/")
def home():
    return {"message":"my FastAPI project is ready"}
    
@app.get("/Sudents")
def student():
    return { "name":"Ali","age":20,"course":"python"}
# Out:
# Writing FastApi.py
